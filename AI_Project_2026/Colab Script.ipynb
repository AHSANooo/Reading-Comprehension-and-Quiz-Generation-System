# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 2. Navigate to your project directory
# %cd /content/drive/MyDrive/AI_Project_2026

# 3. Install requirements (rouge-score, nltk, etc.)
# !pip install -r requirements.txt

# 4. Download required NLTK datasets for Model B's POS tagging
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

# 5. Execute the Pipeline
print("--- Starting Data Split ---")
# !python src/data_splitter.py

print("\n--- Starting Preprocessing ---")
# !python src/preprocessing.py

print("\n--- Training Model A ---")
# !python src/model_a_train.py

print("\n--- Training Model B ---")
# !python src/model_b_train.py

print("\n--- Pipeline Complete! Check your /models folder. ---")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/AI_Project_2026
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# --- Starting Data Split ---
# [INFO] Not running in an interactive Colab kernel — skipping Drive mount.
# [→] Loading raw dataset from: /content/drive/MyDrive/AI_Project_2026/dataset/dev.csv
#     Total rows loaded: 87,866
# [✓] Split complete.
#     Train : 70,292 rows  →  /content/drive/MyDrive/AI_Project_2026/processed/train.csv
#     Val   :  8,787 rows  →  /content/drive/MyDrive/AI_Project_2026/processed/val.csv
#     Test  :  8,787 rows  →  /content/drive/MyDrive/AI_Project_2026/processed/test.csv
#
# ...
